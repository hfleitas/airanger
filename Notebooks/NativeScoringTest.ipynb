-- %% [markdown]
-- # Native scoring using the PREDICT T-SQL function with SQL machine learning
--
-- <span style="font-size: 14px;"><a href="https://docs.microsoft.com/en-us/sql/machine-learning/predictions/native-scoring-predict-transact-sql" data-href="https://docs.microsoft.com/en-us/sql/machine-learning/predictions/native-scoring-predict-transact-sql" title="https://docs.microsoft.com/en-us/sql/machine-learning/predictions/native-scoring-predict-transact-sql" is-markdown="true" is-absolute="false">https://docs.microsoft.com/en-us/sql/machine-learning/predictions/native-scoring-predict-transact-sql</a></span>

-- %%
if db_id('NativeScoringTest') is null CREATE DATABASE NativeScoringTest;
GO
USE NativeScoringTest;
GO
DROP TABLE IF EXISTS iris_rx_data;
GO
CREATE TABLE iris_rx_data (
    "Sepal.Length" float not null, "Sepal.Width" float not null
  , "Petal.Length" float not null, "Petal.Width" float not null
  , "Species" varchar(100) null
);
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.196

-- %%
INSERT INTO iris_rx_data ("Sepal.Length", "Sepal.Width", "Petal.Length", "Petal.Width" , "Species")
EXECUTE sp_execute_external_script
  @language = N'R'
  , @script = N'iris_data <- iris;'
  , @input_data_1 = N''
  , @output_data_1_name = N'iris_data';
GO
-- Out:
-- (150 rows affected)
-- Total execution time: 00:00:00.287

-- %%
DROP TABLE IF EXISTS ml_models;
GO
CREATE TABLE ml_models ( model_name nvarchar(100) not null primary key
  , model_version nvarchar(100) not null
  , native_model_object varbinary(max) not null);
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.151

-- %%
DECLARE @model varbinary(max);
EXECUTE sp_execute_external_script
  @language = N'R'
  , @script = N'
    iris.sub <- c(sample(1:50, 25), sample(51:100, 25), sample(101:150, 25))
    iris.dtree <- rxDTree(Species ~ Sepal.Length + Sepal.Width + Petal.Length + Petal.Width, data = iris[iris.sub, ])
    model <- rxSerializeModel(iris.dtree, realtimeScoringOnly = TRUE)
    '
  , @params = N'@model varbinary(max) OUTPUT'
  , @model = @model OUTPUT
  INSERT [dbo].[ml_models]([model_name], [model_version], [native_model_object])
  VALUES('iris.dtree','v1', @model) ;
-- Out:
-- STDOUT message(s) from external script:
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.007 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.007 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.009 seconds
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: Less than .001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.014 seconds
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: 0.001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.017 seconds
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: Less than .001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.008 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.010 seconds
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: Less than .001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.018 seconds
-- STDOUT message(s) from external script:
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: 0.001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: Less than .001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.006 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.009 seconds
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: 0.002 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.017 seconds
-- Rows Read: 2, Total Rows Processed: 2, Total Chunk Time: 0.001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: Less than .001 seconds
-- Rows Read: 75, Total Rows Processed: 75, Total Chunk Time: 0.001 seconds
--
-- Elapsed time for DTreeEstimation: 0.281 secs.
--
-- Elapsed time for BxDTreeBase: 0.284 secs.
-- (1 row affected)
-- Total execution time: 00:00:00.644

-- %%
SELECT *, datalength(native_model_object)/1024. as model_size_kb
FROM ml_models;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.051
-- <table><tr><th>model_name</th><th>model_version</th><th>native_model_object</th><th>model_size_kb</th></tr><tr><td>iris.dtree</td><td>v1</td><td>...</td><td>5.058593</td></tr></table>

-- %%
DECLARE @model varbinary(max) = (
  SELECT native_model_object
  FROM ml_models
  WHERE model_name = 'iris.dtree'
  AND model_version = 'v1');
SELECT d.*, p.*
  FROM PREDICT(MODEL = @model, DATA = dbo.iris_rx_data as d)
  WITH(setosa_Pred float, versicolor_Pred float, virginica_Pred float) as p;
go
-- Out:
-- (150 rows affected)
-- Total execution time: 00:00:00.132
-- <table><tr><th>Sepal.Length</th><th>Sepal.Width</th><th>Petal.Length</th><th>Petal.Width</th><th>Species</th><th>setosa_Pred</th><th>versicolor_Pred</th><th>virginica_Pred</th></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.9</td><td>3</td><td>1.4</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.7</td><td>3.2</td><td>1.3</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.6</td><td>3.1</td><td>1.5</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5</td><td>3.6</td><td>1.4</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.4</td><td>3.9</td><td>1.7</td><td>0.4</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.6</td><td>3.4</td><td>1.4</td><td>0.3</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5</td><td>3.4</td><td>1.5</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.4</td><td>2.9</td><td>1.4</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.1</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.4</td><td>3.7</td><td>1.5</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.6</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.8</td><td>3</td><td>1.4</td><td>0.1</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.3</td><td>3</td><td>1.1</td><td>0.1</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.8</td><td>4</td><td>1.2</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.7</td><td>4.4</td><td>1.5</td><td>0.4</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.4</td><td>3.9</td><td>1.3</td><td>0.4</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.1</td><td>3.5</td><td>1.4</td><td>0.3</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.7</td><td>3.8</td><td>1.7</td><td>0.3</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.1</td><td>3.8</td><td>1.5</td><td>0.3</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.7</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.1</td><td>3.7</td><td>1.5</td><td>0.4</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.6</td><td>3.6</td><td>1</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.1</td><td>3.3</td><td>1.7</td><td>0.5</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.8</td><td>3.4</td><td>1.9</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5</td><td>3</td><td>1.6</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5</td><td>3.4</td><td>1.6</td><td>0.4</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.2</td><td>3.5</td><td>1.5</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.2</td><td>3.4</td><td>1.4</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.7</td><td>3.2</td><td>1.6</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.8</td><td>3.1</td><td>1.6</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.4</td><td>3.4</td><td>1.5</td><td>0.4</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.2</td><td>4.1</td><td>1.5</td><td>0.1</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.5</td><td>4.2</td><td>1.4</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.9</td><td>3.1</td><td>1.5</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5</td><td>3.2</td><td>1.2</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>5.5</td><td>3.5</td><td>1.3</td><td>0.2</td><td>setosa</td><td>1</td><td>0</td><td>0</td></tr><tr><td>4.9</td><td>3.6</td><td>1.4</td><td>0.1</td><td>setosa</td> ...

-- %% [markdown]
-- # Real-time scoring with sp\_rxPredict in SQL Server
--
-- [Real-time scoring using sp\_rxPredict - SQL Server Machine Learning Services | Microsoft Docs](https://docs.microsoft.com/en-us/sql/machine-learning/predictions/real-time-scoring?view=sql-server-ver15)

-- %%
EXEC sp_configure 'clr enabled', 1;
RECONFIGURE;
GO
-- Out:
-- Configuration option 'clr enabled' changed from 1 to 1. Run the RECONFIGURE statement to install.
-- Total execution time: 00:00:00.045

-- %% [markdown]
-- Run in elevated CMD as Administrator on the VM
-- ```
-- cd C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\R_SERVICES\library\RevoScaleR\rxLibs\x64
-- RegisterRExt.exe /installRts
-- RegisterRExt.exe /installRts /database:NativeScoringTest
-- ```

-- %% [markdown]
-- Run T-SQL

-- %%
use NativeScoringTest
go 
DECLARE @irismodel varbinary(max)
SELECT @irismodel = [native_model_object] from [ml_models]
WHERE model_name = 'iris.dtree' 
AND model_version = 'v1'

EXEC sp_rxPredict
@model = @irismodel,
@inputData = N'SELECT * FROM iris_rx_data'
-- Out:
-- Commands completed successfully.
-- (150 rows affected)
-- Total execution time: 00:00:00.102
-- <table><tr><th>setosa_Pred</th><th>versicolor_Pred</th><th>virginica_Pred</th></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>1</td><td>0</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>0.10714285714285714</td><td>0.8928571428571429</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>0.10714285714285714</td><td>0.8928571428571429</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>0.10714285714285714</td><td>0.8928571428571429</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>0.10714285714285714</td><td>0.8928571428571429</td></tr><tr><td>0</td><td>0.10714285714285714</td><td>0.8928571428571429</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>0.10714285714285714</td><td>0.8928571428571429</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><tr><td>0</td><td>1</td><td>0</td></tr><t ...
